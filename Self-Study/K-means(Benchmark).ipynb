# %%
## Import Library
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
## Load Data
dfa = pd.read_csv("/content/Mall_Customers.csv")
dfa = dfa[['Age','Annual Income (k$)']]
print('Total Row : ', len(dfa))
# Out:
# Total Row :  200

# %%
## Feature Scaling
sc_dfa = StandardScaler()
dfa_std = sc_dfa.fit_transform(dfa.astype(float))

# %%
## Clustering with KMeans
kmeans = KMeans(n_clusters=3, random_state=42).fit(dfa_std)
labels = kmeans.labels_
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
new_dfa = pd.DataFrame(data = dfa_std, columns = ['Age','Annual Income (k$)'])
new_dfa['label_kmeans'] = labels

# %%
fig, ax = plt.subplots(figsize=(10,7))
plt.scatter(new_dfa["Annual Income (k$)"][new_dfa["label_kmeans"] == 0], new_dfa["Age"][new_dfa["label_kmeans"] == 0],
            color = "blue", s=100, edgecolor='green',linestyle='--')
plt.scatter(new_dfa["Annual Income (k$)"][new_dfa["label_kmeans"] == 1], new_dfa["Age"][new_dfa["label_kmeans"] == 1],
            color = "red", s=100, edgecolor='green',linestyle='--')
plt.scatter(new_dfa["Annual Income (k$)"][new_dfa["label_kmeans"] == 2], new_dfa["Age"][new_dfa["label_kmeans"] == 2],
            color = "green", s=100, edgecolor='green',linestyle='--')
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=500);
ax.set_xlabel('Annual Income (k$)')
ax.set_ylabel('Age')
plt.show()

# %%
## Load Data
dfa = pd.read_csv("/content/Mall_Customers.csv");dfa
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
# Carregando os dados
dfa = pd.read_csv("/content/Mall_Customers.csv")
dfa = dfa[['Age', 'Annual Income (k$)', 'Spending Score (1-100)']]
print('Total Row : ', len(dfa))

# Feature Scaling
sc_dfa = StandardScaler()
dfa_std = sc_dfa.fit_transform(dfa.astype(float))

# Clustering with KMeans
kmeans = KMeans(n_clusters=3, random_state=42).fit(dfa_std)
labels = kmeans.labels_
new_dfa = pd.DataFrame(data=dfa_std, columns=['Age', 'Annual Income (k$)', 'Spending Score (1–100)'])
new_dfa['label_kmeans'] = labels

# Criando a figura e o eixo 3D
fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(111, projection="3d")

# Plotando os clusters
ax.scatter(new_dfa.Age[new_dfa.label_kmeans == 0],
           new_dfa["Annual Income (k$)"][new_dfa.label_kmeans == 0],
           new_dfa["Spending Score (1–100)"][new_dfa.label_kmeans == 0],
           c="blue", s=100, edgecolor="green")

ax.scatter(new_dfa.Age[new_dfa.label_kmeans == 1],
           new_dfa["Annual Income (k$)"][new_dfa.label_kmeans == 1],
           new_dfa["Spending Score (1–100)"][new_dfa.label_kmeans == 1],
           c="red", s=100, edgecolor="green")

ax.scatter(new_dfa.Age[new_dfa.label_kmeans == 2],
           new_dfa["Annual Income (k$)"][new_dfa.label_kmeans == 2],
           new_dfa["Spending Score (1–100)"][new_dfa.label_kmeans == 2],
           c="green", s=100, edgecolor="green")

# Plotando os centros dos clusters
centers = kmeans.cluster_centers_
ax.scatter(centers[:, 0], centers[:, 1], centers[:, 2], c='black', s=500)

# Definindo rótulos dos eixos
plt.xlabel("Age")
plt.ylabel("Annual Income (k$)")
ax.set_zlabel('Spending Score (1–100)')

# Exibindo o gráfico
plt.show()
# Out:
# Total Row :  200
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
